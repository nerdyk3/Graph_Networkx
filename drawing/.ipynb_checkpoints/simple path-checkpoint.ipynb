# %%
import networkx as nx
import matplotlib.pyplot as plt

G= nx.path_graph(8)
print(nx.center(G))
print(nx.diameter(G))
print(nx.eccentricity(G))
print(nx.radius(G))
nx.draw(G)
plt.show()
# Out:
# [3, 4]
# 7
# {0: 7, 1: 6, 2: 5, 3: 4, 4: 4, 5: 5, 6: 6, 7: 7}
# 4
