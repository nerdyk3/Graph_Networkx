# %%
import networkx as nx
import matplotlib.pyplot as plt
G=nx.petersen_graph()
plt.subplot(121)
nx.draw(G,with_labels=True,font_width='bold')
plt.subplot(122)
nx.draw_shell(G,nlist=[range(5,10),range(5)], with_labels=True, font_weidth='bold')

# %%
import networkx as nx
options = {
    'node_color': 'red',
    'node_size': 100,
    'width': 3,
    'edge_color':'blue'
}
plt.subplot(221)

nx.draw_random(G, **options)
plt.subplot(222)

nx.draw_circular(G, **options)
plt.subplot(223)

nx.draw_spectral(G, **options)
plt.subplot(224)

nx.draw_shell(G, nlist=[range(5,10),range(5)], **options)
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-13-8e55a6f3f845> in <module>()
#      17 plt.subplot(224)
#      18
# ---> 19 nx.draw_shell(G, nlist=[range(5,10),range(5)], **options)
#
# /home/kunal/.local/lib/python2.7/site-packages/networkx/drawing/nx_pylab.pyc in draw_shell(G, **kwargs)
#    1052     if nlist is not None:
#    1053         del(kwargs['nlist'])
# -> 1054     draw(G, shell_layout(G, nlist=nlist), **kwargs)
#    1055
#    1056
#
# /home/kunal/.local/lib/python2.7/site-packages/networkx/drawing/nx_pylab.pyc in draw(G, pos, ax, **kwds)
#     124
#     125     try:
# --> 126         draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127         ax.set_axis_off()
#     128         plt.draw_if_interactive()
#
# /home/kunal/.local/lib/python2.7/site-packages/networkx/drawing/nx_pylab.pyc in draw_networkx(G, pos, arrows, with_labels, **kwds)
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt
options = {
    'node_color': 'red',
    'node_size': 180,
    'width': 5,
    'edge_color':'green'
}
G = nx.dodecahedral_graph()
shells=[[2,3,4,5,6],[8,1,0,19,18,17,16,15,14,7],[9,10,11,12,13]]
nx.draw_shell(G, nlist=shells,**options)

# %%
import networkx as nx
import matplotlib.pyplot as plt
options = {
    'node_color': 'red',
    'node_size': 180,
    'width': 5,
    'edge_color':'green'
}
G = nx.dodecahedral_graph()
shells=[[2,3,4,5,6],[8,1,0,19,18,17,16,15,14,7],[9,10,11,12,13]]
nx.draw(G)
plt.savefig("dodecahedral.png")

# %%
from networkx.drawing.nx_pydot import write_dot
pos=nx.nx_agraph.graphviz_layout(G)
nx.draw(G,pos=pos)
write_dot(G,'file.dot')

# %%
import networkx as nx
G = nx.Graph()
G.add_edge(1,2)
G.add_edge(2,3,weight=0.9)
list(G)
# Out:
# [1, 2, 3]

# %%
import math
import networkx as nx
G = nx.Graph()
G.add_edge('9','6',function=math.cos)
G.add_node(math.cos)
list(G)
# Out:
# ['9', <function math.cos>, '6']

# %%
import networkx as nx
G = nx.Graph()
e=[('a','b',0.3),('b','c',0.9),('a','c',0.5),('c','d',1.2)]
G.add_weighted_edges_from(e)
print(nx.dijkstra_path(G,'a','d'))
# Out:
# ['a', 'c', 'd']

# %%
import matplotlib.pyplot as plt
import networkx as nx
G = nx.cubical_graph()
plt.subplot(121)
nx.draw(G)
plt.subplot(122)
nx.draw(G, pos=nx.circular_layout(G),nodecolor='red' ,edge_color='blue')

# %%
G=nx.Graph()
G.add_edge('A','B')
G.add_edge('B','C')
print(G.adj)
# Out:
# {'A': {'B': {}}, 'C': {'B': {}}, 'B': {'A': {}, 'C': {}}}

# %%
'A' in G
# Out:
# True

# %%
[n for n in G if n<'B']
# Out:
# ['A']

# %%
len (G)
# Out:
# 3

# %%
class  ThinGraph(nx.Graph):
    all_edge_dict={'wight':1 }
    def single_edge_dict(self):
        return self.all_edge_dict
    edge_attr_dict_factory = single_edge_dict
G= ThinGraph()
G.add_edge(2,1)
G[2][1]
G.add_edge(2,2)
G[2][1] is G[2][2]
# Out:
# True
